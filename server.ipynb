# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install -r '/content/drive/MyDrive/Skincare/AcneAPI/SAHI_new version/requirements.txt'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 55.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pyngrok

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/predict use API/'

from pyngrok import ngrok

# my AuthToken
# !ngrok config add-authtoken 2esGPvfWQI5TMr1B2yQVQEOAuTf_2qiwzsy39BrywdmPv9BCn
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/predict use API/'
# /content/drive/MyDrive/Skincare/AcneAPI/SAHI_new version
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# %cd '/content/drive/MyDrive/Skincare/AcneAPI/SAHI_new version'
# !python server.py
# Out:
# /content/drive/MyDrive/Skincare/AcneAPI/SAHI_new version
# 03/25/2025 12:50:39 - INFO - pyngrok.ngrok -   Opening tunnel named: http-8001-0bc99bc0-cd83-4d72-b026-5a540e69f82c
# 03/25/2025 12:50:39 - INFO - pyngrok.process.ngrok -   t=2025-03-25T12:50:39+0000 lvl=info msg="no configuration paths supplied"
# 03/25/2025 12:50:39 - INFO - pyngrok.process.ngrok -   t=2025-03-25T12:50:39+0000 lvl=info msg="using configuration at default config path" path=/root/.config/ngrok/ngrok.yml
# 03/25/2025 12:50:39 - INFO - pyngrok.process.ngrok -   t=2025-03-25T12:50:39+0000 lvl=info msg="open config file" path=/root/.config/ngrok/ngrok.yml err=nil
# 03/25/2025 12:50:39 - INFO - pyngrok.process.ngrok -   t=2025-03-25T12:50:39+0000 lvl=info msg="starting web service" obj=web addr=127.0.0.1:4040 allow_hosts=[]
# 03/25/2025 12:50:40 - INFO - pyngrok.process.ngrok -   t=2025-03-25T12:50:40+0000 lvl=info msg="client session established" obj=tunnels.session
# ...
